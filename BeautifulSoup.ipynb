cf.jpg
# https://s.yimg.com/uu/api/res/1.2/5SuTAwruIpQGwd_kK.Askg--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/travel.travelleisure.com/58104a5af16eac0e8f59c54166e1d726.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/kO8GV5yN1ipeKTwfwdHRCQ--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/the_cool_down_737/a3ef08135826f3a05480b3d9aa9a8142.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/5yWzaf46VFrIb9rjZvbriQ--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/ap.org/ddd097890e5a4f6932bbea88d4b789af.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/S.uNuipFVeqi_PLN144zGQ--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/harper_s_bazaar_391/07a977b742915f561c64e0707ad52394.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/9lJySSQVBMORZugwnDAo.g--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/vibe_128/f7c2e4c4ef1ef2891ad4bd75e25c5be2.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/ECcS7lLAZPWtChPo7ZSPpQ--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/the_new_republic_521/24f5ab8ca170aa065431ab61cb1ead84.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/rZ.ahSTQo6DQmnd3FwlGYw--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/parade_250/22dc22f7a0d3ef56e7c07d7f9bdd7b7c.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/g3IRN8dblkwCjA88.z57og--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/wnyw_fox_local_articles_540/5c5f3303cddf0ffe4fc7be5a1f31a66a.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/AtgaiU4p_Xqt7tKklg7ivA--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/parade_250/1c2f0658ea608dec755e695a61cecee2.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/6iBFyvylhc0TnT9xAL_dyA--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/theblast_73/a68155bd903ea8b2396510622105e6d3.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/e35M9z0vGefpsFlX.xRmvQ--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/wwd_409/b7d7408f0cb79f4479bcfc78728b953e.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/soDSr3a.m8XShbUWHLrqnA--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/futurism_981/9809086231199ed534cf58225d555907.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/FN5ns5fr6vSkya7q4fRJig--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/people_218/0e319c1762c56d356a9dda2e2f25b473.cf.jpg
# https://s.yimg.com/uu/api/res/1.2/U_Z201Zex.BaE9ykjNF.4g--~B/Zmk9c3RyaW07aD0yODQ7cT04MDt3PTUzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/the_hill_articles_341/c19af5f3136573f59053c6e2ae82f63e.cf.jpg
# https://s.yimg.com/g/images/spaceball.gif
# https://s.yimg.com/g/images/spaceball.gif
# https://s.yimg.com/g/images/spaceball.gif
# https://s.yimg.com/g/images/spaceball.gif
# https://s.yimg.com/g/images/spaceball.gif
# https://s.yimg.com/g/images/spaceball.gif
# https://s.yimg.com/g/images/spaceball.gif
# https://sb.scorecardresearch.com/p?c1=2&c2=7241469&c5=2023538075&c7=https%3A%2F%2Fwww.yahoo.com%2F&c14=-1
# /info/p.gif?apptype=default&beaconType=pageRenderEnd&code=pageRender&bucket=900%2Cseamless&device=desktop&intl=us&rid=1oorigpjhmrda&site=fp&t=1729850795103

# %%
import os
import requests
from bs4 import BeautifulSoup
# Function to download images from the URLs
def download_images(image_urls, folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    for i, url in enumerate(image_urls):
        try:
            image_data = requests.get(url).content
            file_path = os.path.join(folder_name, f'image_{i+1}.jpg')
            with open(file_path, 'wb') as handler:
                handler.write(image_data)
            print(f"Image {i+1} downloaded: {file_path}")
        except Exception as e:
            print(f"Failed to download image {i+1}: {e}")
# Function to scrape image URLs from Google Images using BeautifulSoup
def scrape_images(query, num_images=10):
    # Prepare the Google search URL
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    
    # Send an HTTP request to get the content of the search results page
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    response = requests.get(search_url, headers=headers)
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all image elements ('img' tags)
    img_elements = soup.find_all('img')
    
    # Extract the 'src' attribute of each image tag (thumbnail URLs)
    image_urls = []
    for img in img_elements:
        src = img.get('src')
        if src and src.startswith('http'):
            image_urls.append(src)
        if len(image_urls) >= num_images:
            break
    return image_urls
if __name__ == "__main__":
    # User inputs the search query
    search_title = input("Enter the title of images you want to download: ")
    
    # Scrape image URLs from Google
    image_links = scrape_images(search_title, num_images=10)
    
    # Download images to a folder
    download_images(image_links, folder_name=search_title.replace(' ', '_'))
# Out:
# Image 1 downloaded: bird\image_1.jpg
# Image 2 downloaded: bird\image_2.jpg
# Failed to download image 3: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcQMIMaIGqs57e9OYWSCue8EwOytCnzFvlOPDfFn2UjBWXURLTuLD3X6kO90B9o&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BE4143C4D0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 4 downloaded: bird\image_4.jpg
# Image 5 downloaded: bird\image_5.jpg
# Image 6 downloaded: bird\image_6.jpg
# Image 7 downloaded: bird\image_7.jpg
# Failed to download image 8: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcQGnl90_WgtSchDXTjxkEgp5JbJaiT6xgiJP73xeIUEi8zpiKXOL6sc1XNGfw&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001BE40E536B0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 9 downloaded: bird\image_9.jpg
# Image 10 downloaded: bird\image_10.jpg

# %%
import os
import requests
from bs4 import BeautifulSoup
# Function to download images from the URLs
def download_images(image_urls, folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    for i, url in enumerate(image_urls):
        try:
            image_data = requests.get(url).content
            file_path = os.path.join(folder_name, f'image_{i+1}.jpg')
            with open(file_path, 'wb') as handler:
                handler.write(image_data)
            print(f"Image {i+1} downloaded: {file_path}")
        except Exception as e:
            print(f"Failed to download image {i+1}: {e}")
# Function to scrape image URLs from Google Images using BeautifulSoup
def scrape_images(query, num_images=10):
    # Prepare the Google search URL
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    
    # Send an HTTP request to get the content of the search results page
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    response = requests.get(search_url, headers=headers)
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all image elements ('img' tags)
    img_elements = soup.find_all('img')
    
    # Extract the 'src' attribute of each image tag (thumbnail URLs)
    image_urls = []
    for img in img_elements:
        src = img.get('src')
        if src and src.startswith('http'):
            image_urls.append(src)
        if len(image_urls) >= num_images:
            break
    return image_urls
if __name__ == "__main__":
    # User inputs the search query
    search_title = input("Enter the title of images you want to download: ")
    
    # Scrape image URLs from Google
    image_links = scrape_images(search_title, num_images=10)
    
    # Download images to a folder
    download_images(image_links, folder_name=search_title.replace(' ', '_'))
# Out:
# Image 1 downloaded: mountain\image_1.jpg
# Failed to download image 2: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcS_jH9gqYCATdTMqx8pwGgWS0udQJbYLZaOwxhqIk2CGFqISydGD9Myydnwtg&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D7324DE120>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 3 downloaded: mountain\image_3.jpg
# Failed to download image 4: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRRzLTteBao6BIXt5pv7R3OG3v0UHmyqlrUb2d1jr0Zh0DvHLk8CQompdqYbg&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D7324D1700>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 5 downloaded: mountain\image_5.jpg
# Image 6 downloaded: mountain\image_6.jpg
# Image 7 downloaded: mountain\image_7.jpg
# Image 8 downloaded: mountain\image_8.jpg
# Image 9 downloaded: mountain\image_9.jpg
# Failed to download image 10: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcTswPOfdTRJsVBmsZ7d7_DJH2tFbgmd-Blya2jjVDnDb089RveGvzVjdCA_Bg&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D7324DFEC0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))

# %%
import os
import requests
from bs4 import BeautifulSoup
# Function to download images from the URLs
def download_images(image_urls, folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    for i, url in enumerate(image_urls):
        try:
            image_data = requests.get(url).content
            file_path = os.path.join(folder_name, f'image_{i+1}.jpg')
            with open(file_path, 'wb') as handler:
                handler.write(image_data)
            print(f"Image {i+1} downloaded: {file_path}")
        except Exception as e:
            print(f"Failed to download image {i+1}: {e}")
# Function to scrape image URLs from Google Images using BeautifulSoup
def scrape_images(query, num_images=5):
    # Prepare the Google search URL
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    
    # Send an HTTP request to get the content of the search results page
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    response = requests.get(search_url, headers=headers)
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all image elements ('img' tags)
    img_elements = soup.find_all('img')
    
    # Extract the 'src' attribute of each image tag (thumbnail URLs)
    image_urls = []
    for img in img_elements:
        src = img.get('src')
        if src and src.startswith('http'):
            image_urls.append(src)
        if len(image_urls) >= num_images:
            break
    return image_urls
if __name__ == "__main__":
    # User inputs the search query
    search_title = input("Enter the title of images you want to download: ")
    
    # Scrape image URLs from Google
    image_links = scrape_images(search_title, num_images=10)
    
    # Download images to a folder
    download_images(image_links, folder_name=search_title.replace(' ', '_'))
# Out:
# Image 1 downloaded: headphones\image_1.jpg
# Image 2 downloaded: headphones\image_2.jpg
# Failed to download image 3: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcSu4GOWYXapC4Ylq6EhKPZ1adf6RLkibHknkCODggbBoZ06i9xmZ_WKkupriG8&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D72FC031D0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 4 downloaded: headphones\image_4.jpg
# Image 5 downloaded: headphones\image_5.jpg
# Image 6 downloaded: headphones\image_6.jpg
# Image 7 downloaded: headphones\image_7.jpg
# Image 8 downloaded: headphones\image_8.jpg
# Image 9 downloaded: headphones\image_9.jpg
# Image 10 downloaded: headphones\image_10.jpg

# %%
import os
import requests
from bs4 import BeautifulSoup
# Function to download images from the URLs
def download_images(image_urls, folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    for i, url in enumerate(image_urls):
        try:
            image_data = requests.get(url).content
            file_path = os.path.join(folder_name, f'image_{i+1}.jpg')
            with open(file_path, 'wb') as handler:
                handler.write(image_data)
            print(f"Image {i+1} downloaded: {file_path}")
        except Exception as e:
            print(f"Failed to download image {i+1}: {e}")
# Function to scrape image URLs from Google Images using BeautifulSoup
def scrape_images(query, num_images=20):
    # Prepare the Google search URL
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    
    # Send an HTTP request to get the content of the search results page
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    response = requests.get(search_url, headers=headers)
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all image elements ('img' tags)
    img_elements = soup.find_all('img')
    
    # Extract the 'src' attribute of each image tag (thumbnail URLs)
    image_urls = []
    for img in img_elements:
        src = img.get('src')
        if src and src.startswith('http'):
            image_urls.append(src)
        if len(image_urls) >= num_images:
            break
    return image_urls
if __name__ == "__main__":
    # User inputs the search query
    search_title = input("Enter the title of images you want to download: ")
    
    # Scrape image URLs from Google
    image_links = scrape_images(search_title, num_images=20)
    
    # Download images to a folder
    download_images(image_links, folder_name=search_title.replace(' ', '_'))
# Out:
# Image 1 downloaded: tree\image_1.jpg
# Image 2 downloaded: tree\image_2.jpg
# Image 3 downloaded: tree\image_3.jpg
# Image 4 downloaded: tree\image_4.jpg
# Image 5 downloaded: tree\image_5.jpg
# Image 6 downloaded: tree\image_6.jpg
# Image 7 downloaded: tree\image_7.jpg
# Image 8 downloaded: tree\image_8.jpg
# Image 9 downloaded: tree\image_9.jpg
# Image 10 downloaded: tree\image_10.jpg
# Image 11 downloaded: tree\image_11.jpg
# Failed to download image 12: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcS5bvxcq110eSoSHfaDawxSouzvBgItD78oSjlayz5WsNFGb7-QZadF71UsJH8&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D73315A600>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 13 downloaded: tree\image_13.jpg
# Image 14 downloaded: tree\image_14.jpg
# Image 15 downloaded: tree\image_15.jpg
# Failed to download image 16: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcT_ZR2VTXtKoOzLhXZMg8-gRCdfLwRwlh450DjBpP4gyn0pRQTRyXaclO1dSQ&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D73308CF50>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 17 downloaded: tree\image_17.jpg
# Failed to download image 18: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcQ1dhcx-5yBCZuHcoUOxnfsh50OGIO_FYJqBkecBeMsmTZPxn_9vN6Moy6ITA&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D73308FF50>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Image 19 downloaded: tree\image_19.jpg
# Image 20 downloaded: tree\image_20.jpg

# %%
import os
import requests
from bs4 import BeautifulSoup
# Function to download images from the URLs
def download_images(image_urls, folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    for i, url in enumerate(image_urls):
        try:
            image_data = requests.get(url).content
            file_path = os.path.join(folder_name, f'image_{i+1}.jpg')
            with open(file_path, 'wb') as handler:
                handler.write(image_data)
            print(f"Image {i+1} downloaded: {file_path}")
        except Exception as e:
            print(f"Failed to download image {i+1}: {e}")
# Function to scrape image URLs from Google Images using BeautifulSoup
def scrape_images(query, num_images=20):
    # Prepare the Google search URL
    search_url = f"https://www.bing.com/images/search?q={query}&form=HDRSC3&first=1"
    
    # Send an HTTP request to get the content of the search results page
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    response = requests.get(search_url, headers=headers)
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all image elements ('img' tags)
    img_elements = soup.find_all('img')
    
    # Extract the 'src' attribute of each image tag (thumbnail URLs)
    image_urls = []
    for img in img_elements:
        src = img.get('src')
        if src and src.startswith('http'):
            image_urls.append(src)
        if len(image_urls) >= num_images:
            break
    return image_urls
if __name__ == "__main__":
    # User inputs the search query
    search_title = input("Enter the title of images you want to download: ")
    
    # Scrape image URLs from Google
    image_links = scrape_images(search_title, num_images=20)
    
    # Download images to a folder
    download_images(image_links, folder_name=search_title.replace(' ', '_'))
# Out:
# Image 1 downloaded: book\image_1.jpg
# Image 2 downloaded: book\image_2.jpg
# Image 3 downloaded: book\image_3.jpg
# Image 4 downloaded: book\image_4.jpg
# Image 5 downloaded: book\image_5.jpg
# Image 6 downloaded: book\image_6.jpg
# Image 7 downloaded: book\image_7.jpg
# Image 8 downloaded: book\image_8.jpg
# Image 9 downloaded: book\image_9.jpg
# Image 10 downloaded: book\image_10.jpg
# Image 11 downloaded: book\image_11.jpg
# Image 12 downloaded: book\image_12.jpg
# Image 13 downloaded: book\image_13.jpg
# Image 14 downloaded: book\image_14.jpg
# Image 15 downloaded: book\image_15.jpg
# Image 16 downloaded: book\image_16.jpg
# Image 17 downloaded: book\image_17.jpg
